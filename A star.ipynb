# %%
#A*
import heapq
def heuristic(a, b):
    return abs(a[0] - b[0]) + abs(a[1] - b[1])

def a_star(start, goal, graph):
    frontier = [(0, start)]
    cost_so_far = {start: 0}
    came_from = {start: None}

    while frontier:
        current_cost, current_node = heapq.heappop(frontier)

        if current_node == goal:
            path = []
            while current_node is not None:
                path.append(current_node)
                current_node = came_from[current_node]
            return path[::-1]

        for neighbor in graph[current_node]:
            new_cost = cost_so_far[current_node] + heuristic(current_node, neighbor)
            if neighbor not in cost_so_far or new_cost < cost_so_far[neighbor]:
                cost_so_far[neighbor] = new_cost
                priority = new_cost + heuristic(goal, neighbor)
                heapq.heappush(frontier, (priority, neighbor))
                came_from[neighbor] = current_node

    return None

graph = {
    (0, 0): [(1, 0), (0, 1)],
    (1, 0): [(2, 0)],
    (2, 0): [(2, 1)],
    (0, 1): [(0, 2)],
    (2, 1): [(2, 2)],
    (0, 2): [(1, 2)],
    (1, 2): [(2, 2)],
}

start = (0, 0)
goal = (2, 1)

path = a_star(start, goal, graph)

if path:
    print("Path:", path)
else:
    print("No path found")
# Out:
# Path: [(0, 0), (1, 0), (2, 0), (2, 1)]

# %%
#mem bound A*
import heapq
def heuristic(a, b):
    return abs(a[0] - b[0]) + abs(a[1] - b[1])

def a_star(start, goal, graph):
    frontier = [(0, start)]
    cost_so_far = {start: 0}
    came_from = {start: None}
    memory_used=0

    while frontier:
        current_cost, current_node = heapq.heappop(frontier)

        if current_node == goal:
            path = []
            while current_node is not None:
                path.append(current_node)
                current_node = came_from[current_node]
            return path[::-1]

        if memory_used >= memory_limit:
            return None

        for neighbor in graph[current_node]:
            new_cost = cost_so_far[current_node] + heuristic(current_node, neighbor)
            if neighbor not in cost_so_far or new_cost < cost_so_far[neighbor]:
                cost_so_far[neighbor] = new_cost
                priority = new_cost + heuristic(goal, neighbor)
                heapq.heappush(frontier, (priority, neighbor))
                came_from[neighbor] = current_node
                memeory_used=len(cost_so_far)*4+len(frontier)*8

    return None

graph = {
    (0, 0): [(1, 0), (0, 1)],
    (1, 0): [(2, 0)],
    (2, 0): [(2, 1)],
    (0, 1): [(0, 2)],
    (2, 1): [(2, 2)],
    (0, 2): [(1, 2)],
    (1, 2): [(2, 2)],
}

start = (0, 0)
goal = (2, 1)
memory_limits=[40,60]

for memory_limit in memory_limits:
    print('memory limit=',memory_limit)
    path = a_star(start, goal, graph)
    if path:
        print("Path:", path)
    else:
        print("No path found")
    print("-"*20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 48
#      45 start = (0, 0)
#      46 goal = (2, 1)
# ---> 48 path = a_star(start, goal, graph)
#      50 if path:
#      51     print("Path:", path)
#
# Cell In[5], line 22, in a_star(start, goal, graph)
#      19         current_node = came_from[current_node]
#      20     return path[::-1]
# ---> 22 if memory_used >= memory_limit:
#      23     return None
#      25 for neighbor in graph[current_node]:
#
# NameError: name 'memory_limit' is not defined
