# %%
import sklearn
import matplotlib.pyplot  as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,5,4,5])

# %%
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
slope=model.coef_[0]
intercept=model.intercept_

# %%
plt.plot(X,y,color='green',label='Data')
x_data=np.linspace(min(X),max(X),100)
y_pred=slope*x_data+intercept
plt.plot(x_data,y_pred,color='yellow',label="Linear Regression Line")
plt.xlabel('X')
plt.ylabel('Y')
plt.title("Linear Regression Model")
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Slope:",slope)
print("intercept:",intercept)
# Out:
# Slope: 0.6000000000000002
# intercept: 2.1999999999999993

# %%
new_data=np.array([[6]])
predicted_y=model.predict(new_data)

# %%
print("Predicted value for the new data point: ",predicted_y[0])
# Out:
# Predicted value for the new data point:  5.800000000000001
